# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv(r"C:\Users\vardh\Downloads\book.csv")

# %%
print(books)
# Out:
#       r_index   book_id  best_book_id   work_id  books_count        isbn  \
# 0           1   2767052       2767052   2792775          272   439023483
# 1           2         3             3   4640799          491   439554934
# 2           3     41865         41865   3212258          226   316015849
# 3           4      2657          2657   3275794          487    61120081
# 4           5      4671          4671    245494         1356   743273567
# ...       ...       ...           ...       ...          ...         ...
# 2794     2891   6545536       6545536   6737901           26   545060486
# 2795     2892    808853        808853    251371           21   618164413
# 2796     2893  11082037      11082037  15547563           74   316069418
# 2797     2894    500503        500503    488611           10  189221301X
# 2798     2896  13436373      13436373  18940474            8   545326990
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books.head()
# Out:
#    r_index  book_id  best_book_id  work_id  books_count       isbn  \
# 0        1  2767052       2767052  2792775          272  439023483
# 1        2        3             3  4640799          491  439554934
# 2        3    41865         41865  3212258          226  316015849
# 3        4     2657          2657  3275794          487   61120081
# 4        5     4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780440e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780320e+12              Stephenie Meyer                     2005.0
# 3  9.780060e+12                   Harper Lee                     1960.0
# 4  9.780740e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
sorted_books = books.sort_values(by=['authors', 'original_title'])

# %%
sorted_books.to_csv('sorted_books.csv', index=False)

# %%
sorted_books.head()
# Out:
#       r_index   book_id  best_book_id   work_id  books_count       isbn  \
# 1509     1545    776407        776407   3244521          146  525444440
# 435       444     99107         99107   1225592          244  525467564
# 2571     2648     99111         99111     95547           58  525444475
# 2437     2509  17999892      25843420  24748164           41        NaN
# 1992     2044    495395        495395   2325789           43  743291476
#
#             isbn13                        authors  original_publication_year  \
# 1509  9.780530e+12  A.A. Milne, Ernest H. Shepard                     1928.0
# 435   9.780530e+12  A.A. Milne, Ernest H. Shepard                     1926.0
# 2571  9.780530e+12  A.A. Milne, Ernest H. Shepard                     1926.0
# 2437           NaN                    A.G. Riddle                     2013.0
# 1992  9.780740e+12                    A.J. Jacobs                     2007.0
#
# ...

# %%
sorted_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2799 entries, 1509 to 1981
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   r_index                    2799 non-null   int64
#  1   book_id                    2799 non-null   int64
#  2   best_book_id               2799 non-null   int64
#  3   work_id                    2799 non-null   int64
#  4   books_count                2799 non-null   int64
#  5   isbn                       2689 non-null   object
#  6   isbn13                     2701 non-null   float64
#  7   authors                    2799 non-null   object
#  8   original_publication_year  2798 non-null   float64
#  9   original_title             2799 non-null   object
#  10  title                      2799 non-null   object
#  11  language_code              2639 non-null   object
#  12  average_rating             2799 non-null   float64
# ...

# %%
print(books.isnull().sum())
# Out:
# r_index                        0
# book_id                        0
# best_book_id                   0
# work_id                        0
# books_count                    0
# isbn                         110
# isbn13                        98
# authors                        0
# original_publication_year      1
# original_title                 0
# title                          0
# language_code                160
# average_rating                 0
# ratings_count                  0
# work_ratings_count             0
# work_text_reviews_count        0
# ratings_1                      0
# ratings_2                      0
# ratings_3                      0
# ratings_4                      0
# ratings_5                      0
# image_url                      0
# small_image_url                0
# dtype: int64

# %%
unique_books = books['book_id'].nunique()
total_books = books.shape[0]
print(f"Unique Books: {unique_books}, Total Books: {total_books}")
# Out:
# Unique Books: 2799, Total Books: 2799

# %%
duplicates = total_books - unique_books
print(f"Duplicates: {duplicates}")
# Out:
# Duplicates: 0

# %%
plt.figure(figsize=(5, 5))
plt.hist(books['ratings_count'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('no of books')
plt.ylabel('ratings count')
plt.title('Distribution of Ratings Count')
plt.show()

# %%
print(books['ratings_count'].describe())
# Out:
# count    2.799000e+03
# mean     1.440352e+05
# std      2.767145e+05
# min      1.461000e+04
# 25%      4.635250e+04
# 50%      6.808400e+04
# 75%      1.257575e+05
# max      4.780653e+06
# Name: ratings_count, dtype: float64

# %%
plt.figure(figsize=(25, 15))
sns.histplot(books['ratings_count'], bins=50, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('ratings_count')
plt.ylabel('no of books')
plt.show()

# %%
plt.figure(figsize=(25, 15))
sns.histplot(books['ratings_1'], bins=100, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('ratings_1')
plt.ylabel('no.of books')
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.histplot(books['ratings_1'], bins=50, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('ratings_2')
plt.ylabel('no of books')
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.histplot(books['ratings_3'], bins=100, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('ratings_3')
plt.ylabel('no of books')
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.histplot(books['ratings_4'], bins=100, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('ratings_4')
plt.ylabel('no of books')
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.histplot(books['ratings_5'], bins=100, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('ratings_5')
plt.ylabel('no of books')
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.hist(books['books_count'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel('books_count')
plt.ylabel('no of books')
plt.title('Distribution of ratings')
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.hist(books['work_text_reviews_count'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel('work reviews count')
plt.ylabel('ratings count')
plt.title('Distribution of ratings')
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.hist(books['work_ratings_count'], bins=500, color='skyblue', edgecolor='black')
plt.xlabel('work ratings count')
plt.ylabel('ratings count')
plt.title('Distribution of ratings')
plt.show()

# %%
books['total_rating'] = books[['ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5']].sum(axis=1)

# %%
books.to_csv('updated_books.csv', index=False)

# %%
books.head()
# Out:
#    r_index  book_id  best_book_id  work_id  books_count       isbn  \
# 0        1  2767052       2767052  2792775          272  439023483
# 1        2        3             3  4640799          491  439554934
# 2        3    41865         41865  3212258          226  316015849
# 3        4     2657          2657  3275794          487   61120081
# 4        5     4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780440e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780320e+12              Stephenie Meyer                     2005.0
# 3  9.780060e+12                   Harper Lee                     1960.0
# 4  9.780740e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... work_ratings_count  \
# ...

# %%
total_rating = books[['ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5']].sum()

# %%
plt.figure(figsize=(3, 3))
plt.pie(total_rating, labels=total_rating.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Rates')
plt.show()

# %%
rating_count = books[['work_ratings_count','work_text_reviews_count','books_count']].sum()

# %%
plt.figure(figsize=(3, 3))
plt.pie(rating_count, labels=rating_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Rating counts')
plt.show()
